# %%
## A complete text game, the program will let users move through rooms based on user input and get descriptions of each room.
# To create this, you’ll need to establish the direction in which the user can move, a way to track how far the user has moved
# (and therefore which room he/she is in), and to print out a description.
# You’ll also need to set limits for how far the user can move. In other words, create “walls” around the rooms that tell the user,
# “You can’t move further in this direction.”

## Concepts to keep in mind:
# ● Strings
# ● Variables
# ● Input/Output
# ● If/Else Statements
# ● Print
# ● List
# ● Integers

# %%
player = input("Enter player name: ")
game = input("You see a sign that says '" + player + ", follow me to play...') Do you follow or not? (yes/no)").lower().strip()

## start the game:
if game == "yes":
    print("You walk into a room with a large timer on the wall ahead. There are 2 doors. On the left wall is a red door and on the right wall there is green door. \n " 
        "In the same room, there are 3 items that you may first investigate, but you only have enough time to choose 1 before the timer runs out. \n "
        "Which of the following do you choose to investigate? \n 1. A book on a desk \n 2. A rope on a chair \n 3. A diagram on the wall")
    answer = input("Which would you like to investigate? (book/rope/diagram)?").lower().strip()

# if the user selects book:
    if answer == "book":
        print("It is a book titled 'Alice in Borderland' and inside there is a key carved into it.")
        ## room 1: ask the user to choose a door
        room1 = input("Which door do you choose? (red/green)").lower().strip()
        if room1 == "red":
            print("You walk into another room and there are 2 more doors. On the left is a red door and on the right there is a green door.")
            
            ## room 2: ask the user to choose a door
            room2 = input("Which door do you choose? (red/green)").lower().strip()
            if room2 == "red":
                print("You walk into yet another room and there are 2 more doors. On the left is a red door and on the right there is a green door.")
            
                ## room 3: ask the user to choose a door
                room3 = input("Which door do you choose? (red/green)").lower().strip()
                if room3 == "green":
                    print("You managed to escape the building safely and see a large wall that says 'You win this time…' written in blood.")
                else:
            
                    ## make the user play a dice game to choose a final outcome
                    import random
                    input("Press any key to roll your fate")
                    roll = random.randint(1,6)
                    if roll %2 == 0 and answer =="book":
                        print("You rolled a " + str(roll) + ". You find yourself in another room with a window on the other side, but it is locked. \n Poisinous gas starts to fill the room fast, but you manage to open the window using the key in the book. \n Unfortunately, you are very high up from the ground, but you jump anyway and break both your legs then pass out from the pain. \n Too bad " + player + ". Game over!")
                    elif roll %2 == 0 and answer =="rope":
                        print("You rolled a " + str(roll) + ". You find yourself in another room with a window on the other side, but it is locked. \n Poisonous gas starts to fill the room fast, so you repeatedly attempt to break the window by throwing the hook at the glass. It breaks slightly, but not in time. \n Too slow " + player + ". Game over!") 
                    else:
                        print("You rolled a " + str(roll) + ". Poisonous gas leaks into the room and kills you. Game over " + player + "!")
            
            else:
                print("You are showered in acid and then you die. Game over " + player + "!")
        
        else:
            print("You get shot in the face with a shot gun and die. Game over " + player + "!")


# if the user selects rope:
    elif answer == "rope":
        print("Looks like the rope has been used before, there is a hook at the end which is a little bit bloody. But it might come in handy later. Well, maybe…")
        
        ## room 1: ask the user to choose a door
        room1 = input("Which door do you choose? (red/green)").lower().strip()
        if room1 == "red":
            print("You walk into another room and there are 2 more doors. On the left is a red door and on the right there is a green door.")
            
            ## room 2: ask the user to choose a door
            room2 = input("Which door do you choose? (red/green)").lower().strip()
            if room2 == "red":
                print("You walk into yet another room and there are 2 more doors. On the left is a red door and on the right there is a green door.")
            
                ## room 3: ask the user to choose a door
                room3 = input("Which door do you choose? (red/green)").lower().strip()
                if room3 == "green":
                    print("You managed to escape the building safely and see a large wall that says 'You win this time…' written in blood.")
                else:

                    ## make the user play a dice game to choose a final outcome
                    import random
                    input("Press any key to roll your fate")
                    roll = random.randint(1,6)
                    if roll %2 == 0 and answer =="rope":
                        print("You rolled a " + str(roll) + ". You find yourself in another room with a window on the other side, but it is locked. \n Poisonous gas starts to fill the room fast, so you repeatedly attempt to break the window by throwing the hook at the glass. It breaks slightly, but not in time. \n Too slow " + player + ". Game over!") 
                    elif roll %2 == 0 and answer =="book":
                        print("You rolled a " + str(roll) + ". You find yourself in another room with a window on the other side, but it is locked. \n Poisinous gas starts to fill the room fast, but you manage to open the window using the key in the book. \n Unfortunately, you are very high up from the ground, but you jump anyway and break both your legs then pass out from the pain. \n Too bad " + player + ". Game over!")
                    else:
                        print("You rolled a " + str(roll) + ". Poisonous gas leaks into the room and kills you. Game over " + player + "!")
            
            else:
                print("You are showered in acid and then you die. Game over " + player + "!")
        
        else:
            print("You get shot in the face with a shot gun and die. Game over " + player + "!")
        

    # if the user selects diagram:
    elif answer == "diagram":
        print("You find an evacuation map: This depicts directions to a red door, another red door and a green door.")

        room1 = input("Which door do you choose? (red/green)").lower().strip()
        if room1 == "red":
            print("You walk into another room and there are 2 more doors. On the left is a red door and on the right there is a green door.")
        
            ## room 2: ask the user to choose a door
            room2 = input("Which door do you choose? (red/green)").lower().strip()
            if room2 == "red":
                print("You walk into yet another room and there are 2 more doors. On the left is a red door and on the right there is a green door.")
        
                ## room 3: ask the user to choose a door
                room3 = input("Which door do you choose? (red/green)").lower().strip()
                if room3 == "green":
                    print("You managed to escape the building safely and see a large wall that says 'You win this time…' written in blood.")
                else:
                    print("Poisonous gas leaks into the room and kills you. You should have read the map, too bad you can't read this. Game over " + player + "!")
            
            else:
                print("You are showered in acid and then you die. Game over " + player + "!")

        else:
            print("You get shot in the face with a shot gun and die. Game over " + player + "!")
    
    # if the player chooses an item that is not on the list or does not choose an item, create while loop until they pick an item:
    else:
        print("You ran out of time, the room fills with water and you drown. Game over " + player + "!")

## if the player chooses not to play:
else:
    print("You get shot in the head by a red laser from the sky. Game over " + player + "!")
# Out:
# You walk into a room with a large timer on the wall ahead. There are 2 doors. On the left wall is a red door and on the right wall there is green door.
#  In the same room, there are 3 items that you may first investigate, but you only have enough time to choose 1 before the timer runs out.
#  Which of the following do you choose to investigate?
#  1. A book on a desk
#  2. A rope on a chair
#  3. A diagram on the wall
# You find an evacuation map: This depicts directions to a red door, another red door and a green door.
# You walk into another room and there are 2 more doors. On the left is a red door and on the right there is a green door.
# You are showered in acid and then you die. Game over alice!

# %%
## dice game using random
import random
x = random.randint(1, 6)

if x % 2 == 0:
  print("It is an Even Number!")
else:
  print("It is an Odd Number!")
# Out:
# It is an Odd Number!
